# %% [markdown]
# <a href="https://colab.research.google.com/github/bggokmou/BigdataHomework/blob/master/11%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'
wanted_df = pd.read_csv(file)
locations = wanted_df['location']
print(locations)
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 399276       Zimbabwe
# 399277       Zimbabwe
# 399278       Zimbabwe
# 399279       Zimbabwe
# 399280       Zimbabwe
# Name: location, Length: 399281, dtype: object

# %%
kor_df = wanted_df[wanted_df.location == 'South Korea']
kor_date_index_df = kor_df.set_index('date')
fra_df = wanted_df[wanted_df.location == 'France']
fra_date_index_df = fra_df.set_index('date')

# %%
kor_total_cases = kor_date_index_df['total_cases']
fra_total_cases = fra_date_index_df['total_cases']

# %%
target_fra_df = pd.DataFrame({
    'KOR' : kor_total_cases,
    'FRA' : fra_total_cases
    }, index = kor_date_index_df.index)

target_fra_df.iloc[20:50]
# Out:
#               KOR   FRA
# date
# 2020-01-25    1.0   NaN
# 2020-01-26    3.0   3.0
# 2020-01-27    3.0   3.0
# 2020-01-28    3.0   3.0
# 2020-01-29    3.0   3.0
# 2020-01-30    3.0   3.0
# 2020-01-31    3.0   3.0
# 2020-02-01    3.0   3.0
# 2020-02-02   15.0   6.0
# 2020-02-03   15.0   6.0
# 2020-02-04   15.0   6.0
# 2020-02-05   15.0   6.0
# 2020-02-06   15.0   6.0
# 2020-02-07   15.0   6.0
# 2020-02-08   15.0   6.0
# 2020-02-09   27.0  12.0
# 2020-02-10   27.0  12.0
# 2020-02-11   27.0  12.0
# 2020-02-12   27.0  12.0
# 2020-02-13   27.0  12.0
# 2020-02-14   27.0  12.0
# 2020-02-15   27.0  12.0
# 2020-02-16   30.0  12.0
# 2020-02-17   30.0  12.0
# 2020-02-18   30.0  12.0
# 2020-02-19   30.0  12.0
# 2020-02-20   30.0  12.0
# 2020-02-21   30.0  12.0
# 2020-02-22   30.0  12.0
# 2020-02-23  556.0  16.0

# %%
target_fra_df[:].plot.line(rot=45)
# Out:
# <Axes: xlabel='date'>
