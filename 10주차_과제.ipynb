# %% [markdown]
# <a href="https://colab.research.google.com/github/bggokmou/BigdataHomework/blob/master/10%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# 웹 페이지 가져오기
page = requests.get("https://library.gabia.com/")

# HTML 콘텐츠 파싱
soup = bs(page.text, "html.parser")

# 제목과 링크를 포함하는 요소 선택
elements = soup.select('div.esg-entry-content a.eg-grant-element-0')

# 제목과 링크를 저장할 리스트 초기화
titles = []
links = []

# 선택한 요소에서 제목과 링크 추출
for index, element in enumerate(elements, 1):
    titles.append(element.text)
    links.append(element.attrs['href'])

# 데이터를 저장할 DataFrame 생성
df = pd.DataFrame()
df['titles'] = titles
df['links'] = links

# DataFrame을 엑셀 파일로 저장
df.to_excel('./library_gabia.xlsx', sheet_name='Sheet1')

# %%
# 엑셀 파일 읽기
df = pd.read_excel('./library_gabia.xlsx', sheet_name='Sheet1')

# 파일 정보 출력
info = f"인덱스 개수: {df.shape[0]}, 칼럼 개수: {df.shape[1]}, 칼럼 이름: {df.columns.tolist()}"
print(info)

# 데이터의 앞부분 출력 (표 형식)
df.head()
# Out:
# 인덱스 개수: 386, 칼럼 개수: 3, 칼럼 이름: ['Unnamed: 0', 'titles', 'links']
#    Unnamed: 0                                     titles  \
# 0           0  Amazon Lightsail이란? | 월 $3.5로 1TB 클라우드 쓰기
# 1           1                   웹사이트 운영하려면? 도메인과 호스팅 필수!
# 2           2       최대 1억 원 혜택! AWS Lift로 클라우드 저렴하게 쓰세요.
# 3           3                   하이브리드 클라우드란? 정의와 특징 톺아보기
# 4           4                          세금계산서 역발행 쉽게하는 방법
#
#                                                links
# 0  https://library.gabia.com/contents/aws-content...
# 1   https://library.gabia.com/contents/domain/13153/
# 2          https://library.gabia.com/contents/13045/
# 3  https://library.gabia.com/contents/infrahostin...
# 4  https://library.gabia.com/contents/groupware/1...
